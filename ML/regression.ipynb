# %%
import os
os.chdir("C:/Users/Yadavalli/Desktop/ML")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
adm=pd.read_csv('Admission_Predict.csv')

# %%
adm
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
import seaborn as sns
sns.distplot(adm['GRE Score'])

# %%
sns.distplot(adm['TOEFL Score'])

# %%
sns.distplot(adm['University Rating'])

# %%
sns.distplot(adm['SOP'])

# %%
sns.distplot(adm['LOR '])

# %%
sns.distplot(adm['CGPA'])

# %%
sns.heatmap(adm.corr(),annot=True)

# %%
adm.boxplot(column='Chance of Admit ',by='CGPA')

# %%
adm=adm.drop(['Serial No.'],axis=1)

# %%
adm
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# 5          330          115                  5  4.5   3.0  9.34         1
# 6          321          109                  3  3.0   4.0  8.20         1
# 7          308          101                  2  3.0   4.0  7.90         0
# 8          302          102                  1  2.0   1.5  8.00         0
# 9          323          108                  3  3.5   3.0  8.60         0
# 10         325          106                  3  3.5   4.0  8.40         1
# 11         327          111                  4  4.0   4.5  9.00         1
# ...

# %%
adm.describe() #describe comand gives some outine info (descriptive staticstics)
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
adm.cov()
# Out:
#                     GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score          131.644555    58.216967           8.778791  7.079699
# TOEFL Score         58.216967    36.838997           4.828697  4.021053
# University Rating    8.778791     4.828697           1.308114  0.845865
# SOP                  7.079699     4.021053           0.845865  1.013784
# LOR                  5.747726     3.095965           0.678352  0.660025
# CGPA                 5.699742     2.998337           0.509117  0.431183
# Research             3.318690     1.481729           0.255232  0.222807
# Chance of Admit      1.313271     0.685179           0.116009  0.097028
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          5.747726  5.699742  3.318690          1.313271
# TOEFL Score        3.095965  2.998337  1.481729          0.685179
# University Rating  0.678352  0.509117  0.255232          0.116009
# ...

# %%
adm.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835977           0.668976  0.612831
# TOEFL Score         0.835977     1.000000           0.695590  0.657981
# University Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# Chance of Admit     0.802610     0.791594           0.711250  0.675732
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.557555  0.833060  0.580391          0.802610
# TOEFL Score        0.567721  0.828417  0.489858          0.791594
# University Rating  0.660123  0.746479  0.447783          0.711250
# ...

# %%
adm.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
adm.tail()
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 395              0.82
# 396              0.84
# 397              0.91
# 398              0.67
# 399              0.95

# %%
adm.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
mean_adm=adm['Chance of Admit '].mean()
mean_adm
# Out:
# 0.72435

# %%
chance=adm['Chance of Admit ']

# %%
temp=adm['GRE Score']

# %%
x=adm['GRE Score']
y=adm['Chance of Admit ']

# %%
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.

# %%
x_train = x_train.values.reshape((-1,1))
x_test = x_test.values.reshape((-1,1))

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)

# %%
accuracy = model.score(x_train, y_train)
print('Accuracy of the train model between GRE Score and Chance of Admit :', accuracy)
# Out:
# Accuracy of the train model between GRE Score and Chance of Admit : 0.6254287346177885

# %%
accuracy = model.score(x_test, y_test)
print('Accuracy of the test model between GRE Score and Chance of Admit :', accuracy)
# Out:
# Accuracy of the test model between GRE Score and Chance of Admit : 0.6564457263879269

# %%
import statsmodels.api as sm
model=sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                 1.412e+04
# Date:                Tue, 02 Jul 2019   Prob (F-statistic):          1.49e-313
# Time:                        09:59:15   Log-Likelihood:                 272.73
# No. Observations:                 400   AIC:                            -543.5
# Df Residuals:                     399   BIC:                            -539.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# GRE Score      0.0023   1.93e-05    118.843      0.000       0.002       0.002
# ...

# %%
y_train_prediction=model.predict(x_train)
y_test_prediction=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")

# model evaluation for testing set
rmse_testing = (np.sqrt(mean_squared_error(y_test, y_test_prediction)))
r2_testing = r2_score(y_test, y_test_prediction)

print("The model performance for testing set")
print("--------------------------------------")
print('Root mean squared error: ', rmse_testing)
print('R2 score: ', r2_testing)
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.11670382997394606
# R2 score is 0.26907409813116534
#
#
# The model performance for testing set
# --------------------------------------
# Root mean squared error:  0.13039086370248815
# R2 score:  0.24639808352113213

# %%
CAMean=adm['Chance of Admit '].mean()

# %%
#Plot a regression line
import seaborn as sns
plt.plot(x,y,'o')
plt.ylabel("Chance of Admit")
plt.xlabel("GRE Score")
plt.axhline(CAMean, color='r', linestyle='-')
sns.regplot(x='GRE Score', y='Chance of Admit ', data=adm)

# %%
x = adm["TOEFL Score"]
y = adm["Chance of Admit "]

# %%
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.

# %%
x_train = x_train.values.reshape((-1,1))
x_test = x_test.values.reshape((-1,1))

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)

# %%
accuracy = model.score(x_train, y_train)
print('Accuracy of the train model between CGPA and Chance of Admit:', accuracy)
accuracy = model.score(x_test, y_test)
print('Accuracy of the test model between CGPA and Chance of Admit :', accuracy)
# Out:
# Accuracy of the train model between CGPA and Chance of Admit: 0.7586909928008578
# Accuracy of the test model between CGPA and Chance of Admit : 0.7585644965749232

# %%
import statsmodels.api as sm
model=sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                 1.669e+04
# Date:                Tue, 02 Jul 2019   Prob (F-statistic):               0.00
# Time:                        10:27:51   Log-Likelihood:                 305.29
# No. Observations:                 400   AIC:                            -608.6
# Df Residuals:                     399   BIC:                            -604.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# TOEFL Score     0.0068   5.25e-05    129.195      0.000       0.007       0.007
# ...

# %%
y_train_prediction=model.predict(x_train)
y_test_prediction=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")

# model evaluation for testing set
rmse_testing = (np.sqrt(mean_squared_error(y_test, y_test_prediction)))
r2_testing = r2_score(y_test, y_test_prediction)

print("The model performance for testing set")
print("--------------------------------------")
print('Root mean squared error: ', rmse_testing)
print('R2 score: ', r2_testing)
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.10588406532319355
# R2 score is 0.3983216993831896
#
#
# The model performance for testing set
# --------------------------------------
# Root mean squared error:  0.12243583779511891
# R2 score:  0.335546207242458

# %%
import seaborn as sns
plt.plot(x,y,'o')
plt.ylabel("Chance of Admit")
plt.xlabel("TOEFL Score")
plt.axhline(CAMean, color='r', linestyle='-')
sns.regplot(x='TOEFL Score', y='Chance of Admit ', data=adm)

# %%
x = adm[["University Rating", "SOP","LOR "]]
y = adm["Chance of Admit "]
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
accuracy = model.score(x_train, y_train)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.6155120237385132

# %%
x = adm[["GRE Score", "TOEFL Score","CGPA","University Rating"]]
y = adm["Chance of Admit "]
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
accuracy = model.score(x_train, y_train)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.7914301872991627

# %%
x = adm[["GRE Score", "TOEFL Score","CGPA","University Rating","SOP"]]
y = adm["Chance of Admit "]
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
accuracy = model.score(x_train, y_train)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.7934641484208379

# %%
x = adm[["GRE Score","CGPA","University Rating"]]
y = adm["Chance of Admit "]
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
accuracy = model.score(x_train, y_train)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.7882054236758643

# %%
x = adm[["GRE Score","CGPA","University Rating"]]
y = adm["Chance of Admit "]
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
accuracy = model.score(x_train, y_train)
print('Accuracy of the model:', accuracy)

(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
       'Research', 'Chance of Admit '],

# %%
x = adm[['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA','Research']]
y = adm["Chance of Admit "]
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state =1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
accuracy = model.score(x_train, y_train)
print('Accuracy of the train model:', accuracy)
# Out:
# Accuracy of the train model: 0.8089860244349504

# %%
accuracy1 = model.score(x_test, y_test)
print('Accuracy of the test  model:', accuracy1)
# Out:
# Accuracy of the test  model: 0.7814130299874588

# %%
x=adm.iloc[:,1:7]
y=adm.iloc[:,7]

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA
# 0          337          118                  4  4.5   4.5  9.65
# 1          324          107                  4  4.0   4.5  8.87
# 2          316          104                  3  3.0   3.5  8.00
# 3          322          110                  3  3.5   2.5  8.67
# 4          314          103                  2  2.0   3.0  8.21
# 5          330          115                  5  4.5   3.0  9.34
# 6          321          109                  3  3.0   4.0  8.20
# 7          308          101                  2  3.0   4.0  7.90
# 8          302          102                  1  2.0   1.5  8.00
# 9          323          108                  3  3.5   3.0  8.60
# 10         325          106                  3  3.5   4.0  8.40
# 11         327          111                  4  4.0   4.5  9.00
# 12         328          112                  4  4.0   4.5  9.10
# 13         307          109                  3  4.0   3.0  8.00
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
# 5      1
# 6      1
# 7      0
# 8      0
# 9      0
# 10     1
# 11     1
# 12     1
# 13     1
# 14     1
# 15     0
# 16     0
# 17     1
# 18     0
# 19     0
# 20     1
# 21     0
# 22     1
# 23     1
# 24     1
# 25     1
# 26     0
# 27     1
# 28     0
# 29     0
#       ..
# 370    0
# 371    1
# 372    1
# 373    1
# 374    0
# 375    0
# 376    0
# 377    0
# 378    0
# 379    1
# 380    1
# 381    1
# 382    1
# 383    0
# 384    1
# 385    1
# 386    0
# 387    0
# 388    0
# 389    1
# 390    0
# 391    0
# 392    1
# 393    0
# 394    1
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Research, Length: 400, dtype: int64

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
X=minmax.fit(x).transform(x)
X
# Out:
# array([[0.94      , 0.92857143, 0.75      , 0.875     , 0.875     ,
#         0.91346154],
#        [0.68      , 0.53571429, 0.75      , 0.75      , 0.875     ,
#         0.66346154],
#        [0.52      , 0.42857143, 0.5       , 0.5       , 0.625     ,
#         0.38461538],
#        ...,
#        [0.8       , 0.85714286, 0.75      , 1.        , 0.875     ,
#         0.84935897],
#        [0.44      , 0.39285714, 0.5       , 0.625     , 0.75      ,
#         0.63461538],
#        [0.86      , 0.89285714, 0.75      , 1.        , 0.75      ,
#         0.91666667]])

# %%
#Splitting the dataset into Training set and Test set
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.4)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA
# 284        340          112                  4  5.0   4.5  9.66
# 133        323          112                  5  4.0   4.5  8.78
# 229        324          111                  4  3.0   3.0  9.01
# 361        334          116                  4  4.0   3.5  9.54
# 328        324          112                  4  4.0   3.5  8.77
# 308        312          108                  3  3.5   3.0  8.53
# 206        315           99                  2  3.5   3.0  7.89
# 342        308          106                  3  3.0   3.0  8.24
# 179        307          102                  3  3.0   3.0  8.27
# 202        340          120                  5  4.5   4.5  9.91
# 70         332          118                  5  5.0   5.0  9.64
# 339        324          107                  5  3.5   4.0  8.66
# 167        313          102                  3  2.0   3.0  8.27
# 26         322          109                  5  4.5   3.5  8.80
# ...

# %%
y_train
# Out:
# 284    1
# 133    0
# 229    1
# 361    1
# 328    1
# 308    0
# 206    0
# 342    0
# 179    0
# 202    1
# 70     1
# 339    1
# 167    0
# 26     0
# 352    1
# 310    1
# 73     1
# 300    0
# 276    1
# 147    1
# 317    0
# 140    1
# 294    1
# 346    0
# 358    0
# 195    1
# 96     0
# 65     0
# 3      1
# 66     0
#       ..
# 364    1
# 106    1
# 148    1
# 57     0
# 296    0
# 377    0
# 44     1
# 216    1
# 334    1
# 277    0
# 394    1
# 254    0
# 368    0
# 371    1
# 25     1
# 2      1
# 362    1
# 311    1
# 264    1
# 301    0
# 385    1
# 137    1
# 180    0
# 232    0
# 247    0
# 214    1
# 51     1
# 218    1
# 288    0
# 194    0
# Name: Research, Length: 240, dtype: int64

# %%
X_test
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA
# 130        339          114                  5  4.0   4.5  9.76
# 176        329          119                  4  4.5   4.5  9.16
# 215        330          116                  5  5.0   4.5  9.36
# 204        298          105                  3  3.5   4.0  8.54
# 263        324          111                  3  2.5   1.5  8.79
# 207        310          102                  3  3.5   4.0  8.02
# 105        316          110                  3  4.0   4.5  8.78
# 243        325          114                  3  3.5   3.0  9.04
# 100        322          107                  3  3.5   3.5  8.46
# 7          308          101                  2  3.0   4.0  7.90
# 117        290          104                  4  2.0   2.5  7.46
# 31         327          103                  3  4.0   4.0  8.30
# 84         340          115                  5  4.5   4.5  9.45
# 14         311          104                  3  3.5   2.0  8.20
# ...

# %%
y_test
# Out:
# 130    1
# 176    1
# 215    1
# 204    0
# 263    1
# 207    1
# 105    1
# 243    1
# 100    1
# 7      0
# 117    0
# 31     1
# 84     1
# 14     1
# 321    1
# 338    1
# 242    1
# 245    1
# 35     1
# 360    1
# 42     1
# 112    1
# 43     0
# 396    1
# 54     0
# 359    0
# 189    1
# 47     0
# 55     0
# 159    0
#       ..
# 23     1
# 262    1
# 200    1
# 197    0
# 211    1
# 373    1
# 313    0
# 95     0
# 272    0
# 332    1
# 123    0
# 363    0
# 175    1
# 5      1
# 45     1
# 154    0
# 279    0
# 165    0
# 192    1
# 217    1
# 250    1
# 142    1
# 28     0
# 353    0
# 90     1
# 322    0
# 113    0
# 83     1
# 72     1
# 374    0
# Name: Research, Length: 160, dtype: int64

# %%
X_train = X_train.values.reshape((-1,1))
X_test = X_test.values.reshape((-1,1))

# %%
y_train_prediction=model.predict(X_train)
y_test_prediction=model.predict(X_test)

# %%
pd.DataFrame(X_train).count()
# Out:
# 0    1440
# dtype: int64

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")

# model evaluation for testing set
rmse_testing = (np.sqrt(mean_squared_error(y_test, y_test_prediction)))
r2_testing = r2_score(y_test, y_test_prediction)

print("The model performance for testing set")
print("--------------------------------------")
print('Root mean squared error: ', rmse_testing)
print('R2 score: ', r2_testing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-be6a02d91459> in <module>()
#       1 from sklearn.metrics import mean_squared_error, r2_score
#       2 import numpy as np
# ----> 3 rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
#       4 r2_training = r2_score(y_train, y_train_prediction)
#       5
#
# NameError: name 'y_train' is not defined
