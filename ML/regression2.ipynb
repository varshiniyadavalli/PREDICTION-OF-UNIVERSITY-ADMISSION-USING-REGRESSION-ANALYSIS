# %%
import os
os.chdir("C:/Users/Yadavalli/Desktop/datasets")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Yadavalli\\Desktop\\datasets'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("Admission_Predict.csv")

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
data.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Chance of Admit      0.042336   0.802610     0.791594           0.711250
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138          0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391          0.802610
# ...

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data.boxplot(column='Chance of Admit ',by='CGPA')

# %%
data.boxplot(column='Chance of Admit ',by='Research')

# %%
data.boxplot(column='Chance of Admit ',by='TOEFL Score')

# %%
import seaborn as sns
sns.distplot(data['Research'])
# Out:
# C:\Users\Yadavalli\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.boxplot(column='Chance of Admit ',by='University Rating')

# %%
data.boxplot(column='Chance of Admit ',by='SOP')

# %%
data.boxplot(column='Chance of Admit ',by='LOR ')

# %%
data.boxplot(column='Chance of Admit ',by='GRE Score')

# %%
data['CGPA'].hist(bins=10)

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
x = data[["GRE Score", "TOEFL Score","University Rating","SOP","LOR ","CGPA","Research"]]
y = data["Chance of Admit "]

# %%
import statsmodels.api as sm
model1 = sm.OLS(y,x).fit()
predictions = model1.predict(x)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     6034.
# Date:                Sun, 30 Jun 2019   Prob (F-statistic):               0.00
# Time:                        17:09:16   Log-Likelihood:                 491.14
# No. Observations:                 400   AIC:                            -968.3
# Df Residuals:                     393   BIC:                            -940.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
x_train=x_train.values.reshape((-1,1))
x_test=x_test.values.reshape((-1,1))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.4, random_state=1)

# %%
y_train
# Out:
# 163    0.68
# 247    0.71
# 378    0.56
# 145    0.81
# 251    0.70
# 42     0.53
# 160    0.57
# 230    0.73
# 191    0.87
# 238    0.70
# 344    0.47
# 392    0.84
# 330    0.80
# 285    0.93
# 192    0.86
# 147    0.83
# 304    0.62
# 100    0.71
# 34     0.94
# 110    0.61
# 175    0.85
# 245    0.81
# 135    0.82
# 374    0.39
# 154    0.80
# 19     0.62
# 142    0.92
# 158    0.61
# 273    0.52
# 44     0.91
#        ...
# 317    0.58
# 319    0.80
# 7      0.68
# 141    0.90
# 86     0.72
# 352    0.64
# 241    0.65
# 215    0.93
# 68     0.68
# 50     0.76
# 156    0.70
# 252    0.71
# 357    0.68
# 254    0.85
# 276    0.89
# 178    0.72
# 281    0.80
# 237    0.86
# 71     0.96
# 129    0.92
# 144    0.80
# 335    0.83
# 133    0.79
# 203    0.97
# 393    0.77
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: Chance of Admit , Length: 240, dtype: float64

# %%
features = x_train.iloc[:,:].values

# %%
features
# Out:
# array([[317.  , 105.  ,   3.  , ...,   3.  ,   8.56,   0.  ],
#        [311.  , 104.  ,   2.  , ...,   3.5 ,   8.48,   0.  ],
#        [303.  ,  98.  ,   1.  , ...,   2.5 ,   7.65,   0.  ],
#        ...,
#        [325.  , 107.  ,   3.  , ...,   3.5 ,   9.11,   1.  ],
#        [326.  , 111.  ,   5.  , ...,   4.  ,   9.23,   1.  ],
#        [300.  , 105.  ,   1.  , ...,   2.  ,   7.8 ,   0.  ]])

# %%
labels = y_train.iloc[:].values

# %%
labels
# Out:
# array([0.68, 0.71, 0.56, 0.81, 0.7 , 0.53, 0.57, 0.73, 0.87, 0.7 , 0.47,
#        0.84, 0.8 , 0.93, 0.86, 0.83, 0.62, 0.71, 0.94, 0.61, 0.85, 0.81,
#        0.82, 0.39, 0.8 , 0.62, 0.92, 0.61, 0.52, 0.91, 0.54, 0.85, 0.77,
#        0.93, 0.49, 0.65, 0.46, 0.71, 0.94, 0.5 , 0.86, 0.79, 0.57, 0.43,
#        0.75, 0.46, 0.74, 0.64, 0.71, 0.91, 0.58, 0.82, 0.73, 0.78, 0.79,
#        0.9 , 0.73, 0.88, 0.73, 0.56, 0.65, 0.84, 0.86, 0.69, 0.61, 0.76,
#        0.62, 0.71, 0.78, 0.64, 0.62, 0.88, 0.63, 0.64, 0.75, 0.89, 0.72,
#        0.82, 0.74, 0.74, 0.46, 0.7 , 0.64, 0.81, 0.78, 0.72, 0.72, 0.96,
#        0.71, 0.97, 0.81, 0.93, 0.72, 0.57, 0.89, 0.79, 0.56, 0.95, 0.91,
#        0.59, 0.94, 0.74, 0.85, 0.64, 0.65, 0.61, 0.56, 0.71, 0.86, 0.59,
#        0.47, 0.66, 0.68, 0.47, 0.7 , 0.9 , 0.77, 0.7 , 0.68, 0.69, 0.57,
#        0.76, 0.96, 0.58, 0.48, 0.36, 0.94, 0.84, 0.96, 0.97, 0.86, 0.63,
#        0.52, 0.77, 0.48, 0.79, 0.6 , 0.46, 0.79, 0.64, 0.81, 0.64, 0.63,
# ...

# %%
x=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x,y)

# %%
predictions = model.predict(x)

# %%
accuracy=model.score(x,y)
print('Accuracy of the training model:', accuracy)
# Out:
# Accuracy of the training model: 0.8089860244349504

# %%
features1 = x_test.iloc[:,:].values

# %%
labels1 = y_test.iloc[:].values

# %%
X=features1
Y=labels1

# %%
from sklearn import linear_model as lm
model1=lm.LinearRegression()
results1=model1.fit(X,Y)

# %%
predictions = model1.predict(X)

# %%
accuracy=model1.score(X,Y)
print('Accuracy of the test model:', accuracy)
# Out:
# Accuracy of the test model: 0.8111841325989696

# %%
plt.scatter(y, predictions)#train data

# %%
from sklearn.metrics import mean_squared_error, r2_score

# printing values
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")


import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 0.00123569  0.00301196  0.01053834 -0.00021071  0.02044726  0.10358629
#   0.02960009]
# Intercept: -0.9934556643670435
#
#
# The model performance
# --------------------------------------
# RMSE is 0.059659691676880754
# R2 score is 0.8089860244349504

# %%
x = data[["GRE Score", "TOEFL Score","CGPA"]]
y = data["Chance of Admit "]

# %%
model1 = sm.OLS(y,x).fit()
predictions = model1.predict(x)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                 1.044e+04
# Date:                Tue, 25 Jun 2019   Prob (F-statistic):               0.00
# Time:                        11:54:04   Log-Likelihood:                 429.89
# No. Observations:                 400   AIC:                            -853.8
# Df Residuals:                     397   BIC:                            -841.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# GRE Score      -0.0051      0.000    -12.409      0.000      -0.006      -0.004
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.4, random_state=1)

# %%
features = x_train.iloc[:,:].values

# %%
features
# Out:
# array([[317.  , 105.  ,   8.56],
#        [311.  , 104.  ,   8.48],
#        [303.  ,  98.  ,   7.65],
#        [320.  , 113.  ,   8.64],
#        [316.  ,  99.  ,   9.  ],
#        [313.  , 107.  ,   8.5 ],
#        [315.  , 103.  ,   7.86],
#        [313.  , 104.  ,   8.65],
#        [323.  , 110.  ,   8.98],
#        [310.  , 104.  ,   8.37],
#        [295.  ,  96.  ,   7.34],
#        [326.  , 112.  ,   9.12],
#        [327.  , 113.  ,   8.66],
#        [331.  , 116.  ,   9.26],
#        [322.  , 114.  ,   8.94],
#        [326.  , 114.  ,   9.11],
#        [313.  , 106.  ,   8.43],
#        [322.  , 107.  ,   8.46],
#        [331.  , 112.  ,   9.8 ],
#        [305.  , 108.  ,   8.48],
#        [320.  , 111.  ,   8.87],
#        [328.  , 110.  ,   9.02],
#        [314.  , 109.  ,   8.77],
#        [315.  , 105.  ,   7.65],
#        [326.  , 108.  ,   8.89],
#        [303.  , 102.  ,   8.5 ],
#        [331.  , 115.  ,   9.44],
#        [306.  , 106.  ,   8.14],
# ...

# %%
labels = y_train.iloc[:].values

# %%
labels
# Out:
# array([0.68, 0.71, 0.56, 0.81, 0.7 , 0.53, 0.57, 0.73, 0.87, 0.7 , 0.47,
#        0.84, 0.8 , 0.93, 0.86, 0.83, 0.62, 0.71, 0.94, 0.61, 0.85, 0.81,
#        0.82, 0.39, 0.8 , 0.62, 0.92, 0.61, 0.52, 0.91, 0.54, 0.85, 0.77,
#        0.93, 0.49, 0.65, 0.46, 0.71, 0.94, 0.5 , 0.86, 0.79, 0.57, 0.43,
#        0.75, 0.46, 0.74, 0.64, 0.71, 0.91, 0.58, 0.82, 0.73, 0.78, 0.79,
#        0.9 , 0.73, 0.88, 0.73, 0.56, 0.65, 0.84, 0.86, 0.69, 0.61, 0.76,
#        0.62, 0.71, 0.78, 0.64, 0.62, 0.88, 0.63, 0.64, 0.75, 0.89, 0.72,
#        0.82, 0.74, 0.74, 0.46, 0.7 , 0.64, 0.81, 0.78, 0.72, 0.72, 0.96,
#        0.71, 0.97, 0.81, 0.93, 0.72, 0.57, 0.89, 0.79, 0.56, 0.95, 0.91,
#        0.59, 0.94, 0.74, 0.85, 0.64, 0.65, 0.61, 0.56, 0.71, 0.86, 0.59,
#        0.47, 0.66, 0.68, 0.47, 0.7 , 0.9 , 0.77, 0.7 , 0.68, 0.69, 0.57,
#        0.76, 0.96, 0.58, 0.48, 0.36, 0.94, 0.84, 0.96, 0.97, 0.86, 0.63,
#        0.52, 0.77, 0.48, 0.79, 0.6 , 0.46, 0.79, 0.64, 0.81, 0.64, 0.63,
# ...

# %%
x=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x,y)

# %%
predictions = model.predict(x)

# %%
accuracy=model.score(x,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.7814824111932579

# %%
x = data[["University Rating","SOP","LOR ","Research"]]
y = data["Chance of Admit "]

# %%
import statsmodels.api as sm
model1 = sm.OLS(y,x).fit()
predictions = model1.predict(x)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Chance of Admit    R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     3561.
# Date:                Tue, 25 Jun 2019   Prob (F-statistic):          7.26e-309
# Time:                        12:04:21   Log-Likelihood:                 275.83
# No. Observations:                 400   AIC:                            -543.7
# Df Residuals:                     396   BIC:                            -527.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.4, random_state=1)

# %%
features = x_train.iloc[:,:].values

# %%
features
# Out:
# array([[3. , 3.5, 3. , 0. ],
#        [2. , 2.5, 3.5, 0. ],
#        [1. , 2. , 2.5, 0. ],
#        [2. , 2. , 2.5, 1. ],
#        [2. , 2.5, 3. , 0. ],
#        [2. , 2.5, 2. , 1. ],
#        [1. , 1.5, 2. , 0. ],
#        [3. , 4. , 4.5, 0. ],
#        [5. , 4. , 5. , 1. ],
#        [3. , 2. , 3.5, 0. ],
#        [2. , 1.5, 2. , 0. ],
#        [4. , 4. , 3.5, 1. ],
#        [3. , 3.5, 3. , 1. ],
#        [5. , 4. , 4. , 1. ],
#        [5. , 4.5, 4. , 1. ],
#        [3. , 3. , 3. , 1. ],
#        [2. , 2.5, 2. , 0. ],
#        [3. , 3.5, 3.5, 1. ],
#        [5. , 4. , 5. , 1. ],
#        [5. , 3. , 3. , 0. ],
#        [4. , 4.5, 3.5, 1. ],
#        [4. , 4. , 2.5, 1. ],
#        [4. , 3.5, 4. , 1. ],
#        [2. , 2. , 2.5, 0. ],
#        [3. , 3. , 3.5, 0. ],
#        [3. , 3.5, 3. , 0. ],
#        [5. , 4. , 3.5, 1. ],
#        [2. , 2. , 2.5, 0. ],
#        [1. , 1. , 1.5, 1. ],
#        [5. , 4.5, 4. , 1. ],
#        [2. , 1.5, 2. , 0. ],
#        [4. , 4. , 4.5, 1. ],
# ...

# %%
labels = y_train.iloc[:].values

# %%
labels
# Out:
# array([0.68, 0.71, 0.56, 0.81, 0.7 , 0.53, 0.57, 0.73, 0.87, 0.7 , 0.47,
#        0.84, 0.8 , 0.93, 0.86, 0.83, 0.62, 0.71, 0.94, 0.61, 0.85, 0.81,
#        0.82, 0.39, 0.8 , 0.62, 0.92, 0.61, 0.52, 0.91, 0.54, 0.85, 0.77,
#        0.93, 0.49, 0.65, 0.46, 0.71, 0.94, 0.5 , 0.86, 0.79, 0.57, 0.43,
#        0.75, 0.46, 0.74, 0.64, 0.71, 0.91, 0.58, 0.82, 0.73, 0.78, 0.79,
#        0.9 , 0.73, 0.88, 0.73, 0.56, 0.65, 0.84, 0.86, 0.69, 0.61, 0.76,
#        0.62, 0.71, 0.78, 0.64, 0.62, 0.88, 0.63, 0.64, 0.75, 0.89, 0.72,
#        0.82, 0.74, 0.74, 0.46, 0.7 , 0.64, 0.81, 0.78, 0.72, 0.72, 0.96,
#        0.71, 0.97, 0.81, 0.93, 0.72, 0.57, 0.89, 0.79, 0.56, 0.95, 0.91,
#        0.59, 0.94, 0.74, 0.85, 0.64, 0.65, 0.61, 0.56, 0.71, 0.86, 0.59,
#        0.47, 0.66, 0.68, 0.47, 0.7 , 0.9 , 0.77, 0.7 , 0.68, 0.69, 0.57,
#        0.76, 0.96, 0.58, 0.48, 0.36, 0.94, 0.84, 0.96, 0.97, 0.86, 0.63,
#        0.52, 0.77, 0.48, 0.79, 0.6 , 0.46, 0.79, 0.64, 0.81, 0.64, 0.63,
# ...

# %%
x=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x,y)

# %%
predictions = model.predict(x)

# %%
accuracy=model.score(x,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.6724179682525959
